# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2,thousands=",",decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_8e4f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e4f5_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_8e4f5_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_8e4f5_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e4f5_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_8e4f5_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_8e4f5_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_8e4f5_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_8e4f5_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_8e4f5_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_8e4f5_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_8e4f5_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-1",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  0.039557  2.169081
# 2023-09-02  3.089518  4.909917
# 2023-09-03  1.701072  4.667502
# 2023-09-04  0.519344  4.506219
# 2023-09-05  3.794470  3.025495
# 2023-09-06  1.610732  0.849847
# 2023-09-07  1.261745  2.469518
# 2023-09-08  3.101395  2.954720
# 2023-09-09  4.010016  0.291278
# 2023-09-10  2.775447  1.591178

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_d9e22_row0_col0, #T_d9e22_row3_col0, #T_d9e22_row5_col1, #T_d9e22_row8_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d9e22_row0_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_d9e22_row1_col0 {
#   background-color: #5fa5cc;
#   color: #f1f1f1;
# }
# #T_d9e22_row1_col1 {
#   background-color: #014c3b;
#   color: #f1f1f1;
# }
# #T_d9e22_row2_col0 {
#   background-color: #e1dcec;
#   color: #000000;
# }
# #T_d9e22_row2_col1 {
#   background-color: #015f4d;
#   color: #f1f1f1;
# }
# #T_d9e22_row3_col1 {
#   background-color: #016b58;
#   color: #f1f1f1;
# }
# #T_d9e22_row4_col0 {
#   background-color: #1887a0;
#   color: #f1f1f1;
# }
# #T_d9e22_row4_col1 {
#   background-color: #65a8ce;
#   color: #f1f1f1;
# }
# #T_d9e22_row5_col0 {
#   background-color: #e6deee;
#   color: #000000;
# }
# #T_d9e22_row6_col0 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_d9e22_row6_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_d9e22_row7_col0 {
#   background-color: #5da4cc;
#   color: #f1f1f1;
# }
# #T_d9e22_row7_col1 {
#   background-color: #6cabd0;
#   color: #f1f1f1;
# }
# #T_d9e22_row8_col0 {
#   background-color: #028189;
#   color: #f1f1f1;
# }
# #T_d9e22_row9_col0 {
#   background-color: #84b2d4;
#   color: #000000;
# }
# #T_d9e22_row9_col1 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# </style>
# <table id="T_d9e22">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9e22_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_d9e22_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9e22_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_d9e22_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_d9e22_row0_col1" class="data row0 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_d9e22_row1_col0" class="data row1 col0" >日照</td>
#       <td id="T_d9e22_row1_col1" class="data row1 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_d9e22_row2_col0" class="data row2 col0" >溫暖</td>
#       <td id="T_d9e22_row2_col1" class="data row2 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_d9e22_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_d9e22_row3_col1" class="data row3 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_d9e22_row4_col0" class="data row4 col0" >日照</td>
#       <td id="T_d9e22_row4_col1" class="data row4 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_d9e22_row5_col0" class="data row5 col0" >溫暖</td>
#       <td id="T_d9e22_row5_col1" class="data row5 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_d9e22_row6_col0" class="data row6 col0" >溫暖</td>
#       <td id="T_d9e22_row6_col1" class="data row6 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_d9e22_row7_col0" class="data row7 col0" >日照</td>
#       <td id="T_d9e22_row7_col1" class="data row7 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_d9e22_row8_col0" class="data row8 col0" >日照</td>
#       <td id="T_d9e22_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_d9e22_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_d9e22_row9_col0" class="data row9 col0" >日照</td>
#       <td id="T_d9e22_row9_col1" class="data row9 col1" >溫暖</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3595a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3595a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3595a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3595a_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3595a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3595a_row1_col0" class="data row1 col0" >-1.979333</td>
#       <td id="T_3595a_row1_col2" class="data row1 col2" >-1.167595</td>
#       <td id="T_3595a_row1_col4" class="data row1 col4" >3.084720</td>
#     </tr>
#     <tr>
#       <th id="T_3595a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3595a_row3_col0" class="data row3 col0" >1.597759</td>
#       <td id="T_3595a_row3_col2" class="data row3 col2" >0.547925</td>
#       <td id="T_3595a_row3_col4" class="data row3 col4" >-0.746403</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
             columns=["A", "B", "C", "D"])
display(df)

def style_negative(v, props=''):
    return props if v < 0 else None

df.style\
.map(style_negative,props='color:red;')
# Out:
#           A         B         C         D
# 0  0.735151  0.407920 -0.435743 -0.166769
# 1  0.206126 -0.399175  0.467358  0.359287
# 2 -1.981578 -1.192954  1.307242  0.133909
# 3  0.565131  0.332930 -0.029821 -0.312774
# 4 -1.640264 -0.456277  1.326574  1.287543
# 5 -1.010921  0.885522  1.606467 -0.333837
# 6 -1.461382 -0.237001 -2.346717  0.165502
# 7  0.220812  0.026232 -0.330190  1.096167
# 8 -2.593628 -1.916804  1.178317 -0.100177
# 9 -1.490606  0.377597  1.116786 -0.813567
# <style type="text/css">
# #T_6e7ae_row0_col2, #T_6e7ae_row0_col3, #T_6e7ae_row1_col1, #T_6e7ae_row2_col0, #T_6e7ae_row2_col1, #T_6e7ae_row3_col2, #T_6e7ae_row3_col3, #T_6e7ae_row4_col0, #T_6e7ae_row4_col1, #T_6e7ae_row5_col0, #T_6e7ae_row5_col3, #T_6e7ae_row6_col0, #T_6e7ae_row6_col1, #T_6e7ae_row6_col2, #T_6e7ae_row7_col2, #T_6e7ae_row8_col0, #T_6e7ae_row8_col1, #T_6e7ae_row8_col3, #T_6e7ae_row9_col0, #T_6e7ae_row9_col3 {
#   color: red;
# }
# </style>
# <table id="T_6e7ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e7ae_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6e7ae_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_6e7ae_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_6e7ae_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e7ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e7ae_row0_col0" class="data row0 col0" >0.735151</td>
#       <td id="T_6e7ae_row0_col1" class="data row0 col1" >0.407920</td>
#       <td id="T_6e7ae_row0_col2" class="data row0 col2" >-0.435743</td>
#       <td id="T_6e7ae_row0_col3" class="data row0 col3" >-0.166769</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e7ae_row1_col0" class="data row1 col0" >0.206126</td>
#       <td id="T_6e7ae_row1_col1" class="data row1 col1" >-0.399175</td>
#       <td id="T_6e7ae_row1_col2" class="data row1 col2" >0.467358</td>
#       <td id="T_6e7ae_row1_col3" class="data row1 col3" >0.359287</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e7ae_row2_col0" class="data row2 col0" >-1.981578</td>
#       <td id="T_6e7ae_row2_col1" class="data row2 col1" >-1.192954</td>
#       <td id="T_6e7ae_row2_col2" class="data row2 col2" >1.307242</td>
#       <td id="T_6e7ae_row2_col3" class="data row2 col3" >0.133909</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e7ae_row3_col0" class="data row3 col0" >0.565131</td>
#       <td id="T_6e7ae_row3_col1" class="data row3 col1" >0.332930</td>
#       <td id="T_6e7ae_row3_col2" class="data row3 col2" >-0.029821</td>
#       <td id="T_6e7ae_row3_col3" class="data row3 col3" >-0.312774</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e7ae_row4_col0" class="data row4 col0" >-1.640264</td>
#       <td id="T_6e7ae_row4_col1" class="data row4 col1" >-0.456277</td>
#       <td id="T_6e7ae_row4_col2" class="data row4 col2" >1.326574</td>
#       <td id="T_6e7ae_row4_col3" class="data row4 col3" >1.287543</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e7ae_row5_col0" class="data row5 col0" >-1.010921</td>
#       <td id="T_6e7ae_row5_col1" class="data row5 col1" >0.885522</td>
#       <td id="T_6e7ae_row5_col2" class="data row5 col2" >1.606467</td>
#       <td id="T_6e7ae_row5_col3" class="data row5 col3" >-0.333837</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e7ae_row6_col0" class="data row6 col0" >-1.461382</td>
#       <td id="T_6e7ae_row6_col1" class="data row6 col1" >-0.237001</td>
#       <td id="T_6e7ae_row6_col2" class="data row6 col2" >-2.346717</td>
#       <td id="T_6e7ae_row6_col3" class="data row6 col3" >0.165502</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e7ae_row7_col0" class="data row7 col0" >0.220812</td>
#       <td id="T_6e7ae_row7_col1" class="data row7 col1" >0.026232</td>
#       <td id="T_6e7ae_row7_col2" class="data row7 col2" >-0.330190</td>
#       <td id="T_6e7ae_row7_col3" class="data row7 col3" >1.096167</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e7ae_row8_col0" class="data row8 col0" >-2.593628</td>
#       <td id="T_6e7ae_row8_col1" class="data row8 col1" >-1.916804</td>
#       <td id="T_6e7ae_row8_col2" class="data row8 col2" >1.178317</td>
#       <td id="T_6e7ae_row8_col3" class="data row8 col3" >-0.100177</td>
#     </tr>
#     <tr>
#       <th id="T_6e7ae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e7ae_row9_col0" class="data row9 col0" >-1.490606</td>
#       <td id="T_6e7ae_row9_col1" class="data row9 col1" >0.377597</td>
#       <td id="T_6e7ae_row9_col2" class="data row9 col2" >1.116786</td>
#       <td id="T_6e7ae_row9_col3" class="data row9 col3" >-0.813567</td>
#     </tr>
#   </tbody>
# </table>
